# %% [markdown]
# # Project 2 Proposal
#
# ### Bojun Li (bojunl), Emilie He (emilieh)

# %% [markdown]
# # Overview
#
# Throughout this project, our main goal is to predict a patient's diagnosis of diabetes based on various demographic and medical features. While doing so, we also hope to identify factors that are more influential in predicting diabetes which would also make a meaningful impact towards society. By training a classification model on the labeled data, we can test how accurately a diabetes diagnosis can be predicted. This is increasingly important as diabetes is a growing concern around the world. Thus, we hope to leverage past patient data to streamline the process of diagnosing diabetes.

# %% [markdown]
# ## Motivation
#
# Recently, the International Diabetes Federation (IDF) released a statistic that globally, approximately one in nine adults (total 589 million) are living with diabetes, with an estimated 252 million who are unaware of their condition. This peaked our interest in the topic as well as the medical field in general.
#
# With the increasing amount of available healthcare data (including a surprising amount of freely available anonymized data), interest in applying machine learning techniques to diagnostic and treatment approaches has risen. Our motivation in this project is to investigate the potential for using machine learning techniques to build a machine learning model that can accurately predict whether an individual has diabetes based on commonly available features. While this is just a proof of concept, in the future more advanced models could help doctors and patients provide and receive better quality care respectively.
#
# Source: https://finance.yahoo.com/news/over-250-million-people-worldwide-090000437.html

# %% [markdown]
# ## Related Work
#
# Bojun has prior experience submitting to using Kaggle competition datasets as part of Introduction to Deep Learning (11-485) coursework, and is also working on a diabetes-related project for the Information Systems consulting project. Both partners also have an interest in applying machine learning to diabetes specifically and biomedical research in general.
#
# Based on the experience and expertise of the group, the dataset seems like a good fit both interest- and skill- wise.

# %% [markdown]
# ## Data
#
# Link to dataset on Kaggle: https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset
#
# The dataset contains anonymous medical records of patients from electronic health records (EHRs) from various healthcare providers. The dataset contains a CSV file, containing the following columns:
#
# *  gender: somewhat erroneously named, refers to the biological sex of the individual
# *  age: age in years of the individual
# *  hypertension: boolean denoting whether the individual has hyptension (a condition where the blood pressure in their arteries is persistently elevated)
# *  heart_disease: boolean denoting whether the individual has heart disease
# *  smoking_history: variable that represents the individuals smoking history (includes "never", "former", "current", "not current", and "no info")
# *  bmi: BMI of the individual
# *  HbA1c_level: Hemoglobin A1c level is a measure of the individual's average blood sugar level over the past 2-3 months
# *  blood_glucose_level: amount of glucose in the individual's bloodstream at a given time
#
# and
#
# *  diabetes: the target boolean variable being predicted; 1 indicates the presence of diabetes and 0 indicates the opposite
#
# For our data preparation, we plan on handling the missing values and encoding categorical features for easier analysis. Additionally, we will standardize the numerical attributes like BMI or glucose level and create bins for numerical variables like age groups if needed. For testing purposes, we will do an 80/20 split of our dataset to separate our data into training and test sets.

# %% [markdown]
# ## Project Domain and Setup

# %% [markdown]
# ### Type of Learning
#
# We plan to use supervised learning and more specifically, binary classification; the dataset contains a target boolean variable (whether a patient has diabetes or not), which make supervised learning appropriate for this task. We plan to split the dataset into training, validation, and test datasets, train a model on the training data and fine-tune said model on the validation data before doing a final evaluation of the model on the test data, which of course is a common setup in supervised learning tasks. We will test both logistic regression and decision trees as potential models of choice and evaluate the performances based on its overall correctness.

# %% [markdown]
# ### Task, Performance, and Features
#
# The broader domain of our project is healthcare and healthcare informatics.
#
# *   The task (T) in our domain is a binary classification task. Essentially, the task is, using the given features, classify people into "having diabetes" and "not having diabetes".
# *   The experience (E) are the features we outlined above: gender, age, hypertension, heart disease, smoking history, BMI, and blood glucose levels.
# *   The performance metric (P) that we plan to use is accuracy: more specifically the percentage of individuals in the test dataset that the model we train correctly classifies.Additionally, we'll provide a confusion matrix that provides a visual summary of the correct and incorrect predivtions.
#
# Overall, we aim to provide a potentially faster way to indicate if a patient has diabetes or not.
